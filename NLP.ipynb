# %% [markdown]
# <a href="https://colab.research.google.com/github/vishweshwarank-2006/Hands-on-AI-ML-Workshop-Implementations/blob/main/NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import nltk

# %%
text = """Python is a widely used programming language because it is easy to learn and works well for many fields like web development, data science, and automation. As a result, Python programmers are in high demand, with many companies looking for people who can use it to solve real-world problems."""

# %%
from nltk.tokenize import word_tokenize

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
word_final = word_tokenize(text)

# %%
word_final
# Out:
# ['Python',
#  'is',
#  'a',
#  'widely',
#  'used',
#  'programming',
#  'language',
#  'because',
#  'it',
#  'is',
#  'easy',
#  'to',
#  'learn',
#  'and',
#  'works',
#  'well',
#  'for',
#  'many',
#  'fields',
#  'like',
#  'web',
#  'development',
#  ',',
#  'data',
#  'science',
#  ',',
#  'and',
#  'automation',
#  '.',
#  'As',
#  'a',
#  'result',
#  ',',
#  'Python',
#  'programmers',
#  'are',
#  'in',
#  'high',
#  'demand',
#  ',',
#  'with',
#  'many',
#  'companies',
#  'looking',
#  'for',
#  'people',
#  'who',
#  'can',
#  'use',
#  'it',
#  'to',
#  'solve',
#  'real-world',
#  'problems',
#  '.']

# %%
len (word_final)
# Out:
# 55

# %%
from nltk.corpus import stopwords
nltk.download("stopwords")
stopwords.words("english")
final_word = []

from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stem_word=[]
for i in word_final:
  if i not in stopwords.words("english"):
    final_word.append(i)
    stem_word.append(stemmer.stem(i))

# %%
len(final_word)
# Out:
# 37

# %%
stopwords
# Out:
# <WordListCorpusReader in '/root/nltk_data/corpora/stopwords'>

# %%
df= pd.DataFrame()
df['final_word'] = final_word
df ['stem_word'] = stem_word
df
# Out:
#      final_word   stem_word
# 0        Python      python
# 1        widely        wide
# 2          used         use
# 3   programming     program
# 4      language     languag
# 5          easy        easi
# 6         learn       learn
# 7         works        work
# 8          well        well
# 9          many        mani
# 10       fields       field
# 11         like        like
# 12          web         web
# 13  development     develop
# 14            ,           ,
# 15         data        data
# 16      science      scienc
# 17            ,           ,
# 18   automation       autom
# 19            .           .
# 20           As          as
# 21       result      result
# 22            ,           ,
# 23       Python      python
# 24  programmers    programm
# 25         high        high
# 26       demand      demand
# 27            ,           ,
# 28         many        mani
# 29    companies     compani
# 30      looking        look
# 31       people       peopl
# ...

# %%
from nltk.stem import WordNetLemmatizer
lemma = WordNetLemmatizer()
nltk.download("wordnet")
final_words= []
lemma_word=[]
for i in word_final:
  if i not in stopwords.words("english"):
    final_words.append(i)
    lemma_word.append(lemma.lemmatize(i, pos= 'v'))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df['Lemma'] = lemma_word

# %%
df
# Out:
#      final_word   stem_word        Lemma
# 0        Python      python       Python
# 1        widely        wide       widely
# 2          used         use          use
# 3   programming     program      program
# 4      language     languag     language
# 5          easy        easi         easy
# 6         learn       learn        learn
# 7         works        work         work
# 8          well        well         well
# 9          many        mani         many
# 10       fields       field        field
# 11         like        like         like
# 12          web         web          web
# 13  development     develop  development
# 14            ,           ,            ,
# 15         data        data         data
# 16      science      scienc      science
# 17            ,           ,            ,
# 18   automation       autom   automation
# 19            .           .            .
# 20           As          as           As
# 21       result      result       result
# ...
